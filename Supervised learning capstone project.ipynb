# %% [markdown]
# ## GOAL: Create a model to predict whether or not a customer will Churn.

# %%
import pandas as pd

telco_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\Telco-Customer-Churn.csv')
telco_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Part 1: Quick Data Check
#
# **TASK: Confirm quickly with .info() methods the datatypes and non-null values in your dataframe.**

# %%
telco_df.shape
# Out:
# (7032, 21)

# %%
telco_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
telco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# **TASK: Get a quick statistical summary of the numeric columns with .describe() , you should notice that many columns are categorical, meaning you will eventually need to convert them to dummy variables.**

# %%
telco_df.SeniorCitizen
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: SeniorCitizen, Length: 7032, dtype: int64

# %%
telco_df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## Part 2:  Exploratory Data Analysis
#
# ### General Feature Exploration
#
# **TASK: Confirm that there are no NaN cells by displaying NaN values per feature column.**

# %%
telco_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telco_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **TASK: Display the balance of the class labels (Churn) with a Count Plot.**

# %%
import seaborn as sns

sns.countplot(x='Churn', data=telco_df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# **TASK: Explore the distrbution of TotalCharges between Churn categories with a Box Plot or Violin Plot.**

# %%
sns.violinplot(x='Churn', y='TotalCharges', data=telco_df)
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# **TASK: Create a boxplot showing the distribution of TotalCharges per Contract type, also add in a hue coloring based on the Churn class.**

# %%
import matplotlib.pyplot as plt

sns.boxplot(x='Contract', y='TotalCharges', data=telco_df, hue='Churn')
plt.legend(bbox_to_anchor=(1.25, 1), borderaxespad=0)

# %% [markdown]
# **TASK: Create a bar plot showing the correlation of the following features to the class label. Keep in mind, for the categorical features, you will need to convert them into dummy variables first, as you can only calculate correlation for numeric features.**
#
#     ['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines',
#      'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# ***Note, we specifically listed only the features above, you should not check the correlation for every feature, as some features have too many unique instances for such an analysis, such as customerID***

# %%
telco_df.corr()
# Out:
# C:\Users\CICD STUDENT\AppData\Local\Temp\ipykernel_11760\498029725.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   telco_df.corr()
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.015683        0.219874      0.102411
# tenure               0.015683  1.000000        0.246862      0.825880
# MonthlyCharges       0.219874  0.246862        1.000000      0.651065
# TotalCharges         0.102411  0.825880        0.651065      1.000000

# %%
telco_df.corr().shape
# Out:
# C:\Users\CICD STUDENT\AppData\Local\Temp\ipykernel_11760\2642286601.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   telco_df.corr().shape
# (4, 4)

# %%
# converting into dummy variables
telco_corr_df = pd.get_dummies(telco_df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 
 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']]).corr()
telco_corr_df
# Out:
#                                          SeniorCitizen  gender_Female  \
# SeniorCitizen                                 1.000000       0.001819
# gender_Female                                 0.001819       1.000000
# gender_Male                                  -0.001819      -1.000000
# Partner_No                                   -0.016957      -0.001379
# Partner_Yes                                   0.016957       0.001379
# Dependents_No                                 0.210550       0.010349
# Dependents_Yes                               -0.210550      -0.010349
# PhoneService_No                              -0.008392      -0.007515
# PhoneService_Yes                              0.008392       0.007515
# MultipleLines_No                             -0.136377      -0.004335
# MultipleLines_No phone service               -0.008392      -0.007515
# MultipleLines_Yes                             0.142996       0.008883
# ...

# %%
print(telco_corr_df.columns)
telco_corr_df['Churn_Yes'].sort_values().iloc[1:-1]
# Out:
# Index(['SeniorCitizen', 'gender_Female', 'gender_Male', 'Partner_No',
#        'Partner_Yes', 'Dependents_No', 'Dependents_Yes', 'PhoneService_No',
#        'PhoneService_Yes', 'MultipleLines_No',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'StreamingTV_No',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# barplot
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=telco_corr_df['Churn_Yes'].sort_values().iloc[1:-1].index,y=telco_corr_df['Churn_Yes'].sort_values().iloc[1:-1].values)
plt.title("Feature Correlation to Yes Churn")
plt.xticks(rotation=90);

# %% [markdown]
# # Part 3: Churn Analysis
#
# **This section focuses on segementing customers based on their tenure, creating "cohorts", allowing us to examine differences between customer cohort segments.**

# %% [markdown]
# **TASK: What are the 3 contract types available?**

# %%
telco_df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# **TASK: Create a histogram displaying the distribution of 'tenure' column, which is the amount of months a customer was or has been on a customer.**

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=telco_df, x='tenure', bins= 71)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# **TASK: Now use the seaborn documentation as a guide to create histograms separated by two additional features, Churn and Contract.**

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(data=telco_df, x='tenure', bins=71, col='Contract', row='Churn')

# %% [markdown]
# **TASK: Display a scatter plot of Total Charges versus Monthly Charges, and color hue by Churn.**

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.scatterplot(data=telco_df,x='MonthlyCharges',y='TotalCharges',hue='Churn',alpha=0.5,palette='Dark2')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# ### Creating Cohorts based on Tenure
#
# **Let's begin by treating each unique tenure length, 1 month, 2 month, 3 month...N months as its own cohort.**
#
# **TASK: Treating each unique tenure group as a cohort, calculate the Churn rate (percentage that had Yes Churn) per cohort. For example, the cohort that has had a tenure of 1 month should have a Churn rate of 61.99%. You should have cohorts 1-72 months with a general trend of the longer the tenure of the cohort, the less of a churn rate. This makes sense as you are less likely to stop service the longer you've had it.**

# %%
no_churn = telco_df.groupby(['Churn', 'tenure']).count().transpose()['No']
yes_churn = telco_df.groupby(['Churn', 'tenure']).count().transpose()['Yes']

churn_rate = yes_churn * 100 / (no_churn + yes_churn)
churn_rate.transpose()['customerID']
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: customerID, Length: 72, dtype: float64

# %% [markdown]
# **TASK: Now that you have Churn Rate per tenure group 1-72 months, create a plot showing churn rate per months of tenure.**

# %%
plt.figure(figsize=(10, 4), dpi=200)
churn_rate.iloc[0].plot()
plt.ylabel('Churn Percentage');

# %% [markdown]
# ### Broader Cohort Groups
# **TASK: Based on the tenure column values, create a new column called Tenure Cohort that creates 4 separate categories:**
#    * '0-12 Months'
#    * '12-24 Months'
#    * '24-48 Months'
#    * 'Over 48 Months'

# %%
# create cohort function

def cohort(tenure):
    if tenure < 13:
        return '0-12 Months'
    elif tenure < 25:
        return '12-24 Months'
    elif tenure < 49:
        return '24-48 Months'
    else:
        return 'Over 48 Months'

# apply cohort function when adding column to telco_df
telco_df['Tenure Cohort'] = telco_df['tenure'].apply(cohort)

# check first 10 rows of resulting dataframe
telco_df.head(10)[['tenure', 'Tenure Cohort']]
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %% [markdown]
# **TASK: Create a scatterplot of Total Charges versus Monthly Charges,colored by Tenure Cohort defined in the previous task.**

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.scatterplot(data=telco_df,x='MonthlyCharges',y='TotalCharges',hue='Tenure Cohort',alpha=0.5)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# **TASK: Create a count plot showing the churn count per cohort.**

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.countplot(data=telco_df, x='Churn', hue='Tenure Cohort')
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# **TASK: Create a grid of Count Plots showing counts per Tenure Cohort, separated out by contract type and colored by the Churn hue.**

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.catplot(data=telco_df, x='Tenure Cohort', hue='Churn', col='Contract', kind='count')

# %% [markdown]
# # Part 4: Predictive Modeling
#
# **Let's explore 4 different tree based methods: A Single Decision Tree, Random Forest, AdaBoost, Gradient Boosting. Feel free to add any other supervised learning models to your comparisons!**
#
#
# ## Single Decision Tree

# %% [markdown]
# **TASK : Separate out the data into X features and Y label. Create dummy variables where necessary and note which features are not useful and should be dropped.**

# %%
telco_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
X = telco_df.drop(['Churn', 'customerID'], axis=1)
X = pd.get_dummies(X, drop_first=True)
y = telco_df['Churn']

# %% [markdown]
# **TASK: Perform a train test split, holding out 10% of the data for testing. We'll use a random_state of 101 in the solutions notebook/video.**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %% [markdown]
# **TASK: Decision Tree Perfomance. Complete the following tasks:**
#    1. Train a single decision tree model (feel free to grid search for optimal hyperparameters).
#    2. Evaluate performance metrics from decision tree, including classification report and plotting a confusion matrix.
#    2. Calculate feature importances from the decision tree.
#    4. OPTIONAL: Plot your tree, note, the tree could be huge depending on your pruning, so it may crash your notebook if you display it with plot_tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# create object
dt = DecisionTreeClassifier(max_depth=6)

# fit model
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
# test the model on our test dataset
preds = dt.predict(X_test)

# %%
# classification report

from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay,classification_report

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.80       704

# %%
plt.figure(figsize=(6, 2), dpi=200)
ConfusionMatrixDisplay.from_estimator(dt, X_test, y_test)

# %%
# feature importances
imp_features = pd.DataFrame(data=dt.feature_importances_,index=X.columns,columns=['Feature Importance']).sort_values('Feature Importance')

# plot
plt.figure(figsize=(14, 6), dpi=200)
sns.barplot(data=imp_features.sort_values('Feature Importance'), y=imp_features.sort_values('Feature Importance').index, x='Feature Importance')
plt.xticks=90
plt.title('Feature Importance for Decision Tree')
# Out:
# Text(0.5, 1.0, 'Feature Importance for Decision Tree')

# %% [markdown]
# ## Random Forest
#
# **TASK: Create a Random Forest model and create a classification report and confusion matrix from its predicted results on the test set.**

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100)

# train the model
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# predictions

preds = rf.predict(X_test)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.89      0.87       557
#          Yes       0.52      0.45      0.48       147
#
#     accuracy                           0.80       704
#    macro avg       0.69      0.67      0.68       704
# weighted avg       0.79      0.80      0.79       704

# %%
# confusion matrix

ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test)

# %% [markdown]
# ## Boosted Trees
#
# **TASK: Use AdaBoost or Gradient Boosting to create a model and report back the classification report and plot a confusion matrix for its predicted results**

# %%
from sklearn.ensemble import AdaBoostClassifier

# create object/model
ada_model = AdaBoostClassifier()

# train model
ada_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
# test model
preds = ada_model.predict(X_test)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %%
# confusion matrix

ConfusionMatrixDisplay.from_estimator(ada_model, X_test, y_test)

# %% [markdown]
# **TASK: Analyze your results, which model performed best for you?**

# %% [markdown]
# Using base models with Ada Boosting we get the largest accuracy score. Most models performed similarly. We didn't do grid searching.

# %% [markdown]
# ### Great job!
