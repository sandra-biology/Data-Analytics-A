# %%
import pandas as pd

ipl_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\ipl-matches.csv')
ipl_value_counts = ipl_df.value_counts()
ipl_value_counts
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# ...

# %%
ipl_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\ipl-matches.csv')
print(f'ipl_df.columns: {ipl_df.columns}')
# Out:
# ipl_df.columns: Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# find which player has won most potm -> in finals and qualifiers
finals_qual = ipl_df[~(ipl_df['MatchNumber'].str.isdigit())]
finals_qual
# Out:
#           ID           City        Date   Season         MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022               Final
# 1    1312199      Ahmedabad  2022-05-27     2022         Qualifier 2
# 2    1312198        Kolkata  2022-05-25     2022          Eliminator
# 3    1312197        Kolkata  2022-05-24     2022         Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021               Final
# 75   1254116        Sharjah  2021-10-13     2021         Qualifier 2
# 76   1254115        Sharjah  2021-10-11     2021          Eliminator
# 77   1254114          Dubai  2021-10-10     2021         Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21               Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21         Qualifier 2
# 136  1237178      Abu Dhabi  2020-11-06  2020/21          Eliminator
# 137  1237177            NaN  2020-11-05  2020/21         Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019               Final
# ...

# %%
finals_qual = ipl_df[~(ipl_df['MatchNumber'].str.isdigit() | ipl_df['MatchNumber'] == 'Eliminator')]
finals_qual
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
finals_qual = finals_qual[~(finals_qual['MatchNumber'] == 'Eliminator')]
finals_qual
# Out:
#           ID           City        Date   Season         MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022               Final
# 1    1312199      Ahmedabad  2022-05-27     2022         Qualifier 2
# 3    1312197        Kolkata  2022-05-24     2022         Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021               Final
# 75   1254116        Sharjah  2021-10-13     2021         Qualifier 2
# 77   1254114          Dubai  2021-10-10     2021         Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21               Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21         Qualifier 2
# 137  1237177            NaN  2020-11-05  2020/21         Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019               Final
# 195  1181767  Visakhapatnam  2019-05-10     2019           Qualifier
# 197  1181764        Chennai  2019-05-07     2019           Qualifier
# 254  1136620         Mumbai  2018-05-27     2018               Final
# ...

# %%
potm = finals_qual['Player_of_Match'].value_counts()
print(f'len(potm): {len(potm)}')
potm
# Out:
# len(potm): 38
# F du Plessis         3
# KA Pollard           3
# SR Watson            2
# JJ Bumrah            2
# M Vijay              2
# YK Pathan            2
# MK Pandey            2
# SK Raina             2
# A Kumble             2
# MM Patel             1
# CH Gayle             1
# DE Bollinger         1
# MS Dhoni             1
# AC Gilchrist         1
# MS Bisla             1
# MEK Hussey           1
# Harbhajan Singh      1
# UT Yadav             1
# V Sehwag             1
# HH Pandya            1
# RG Sharma            1
# A Nehra              1
# Rashid Khan          1
# DA Miller            1
# VR Iyer              1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# SA Yadav             1
# KH Pandya            1
# JC Buttler           1
# KV Sharma            1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# AB de Villiers       1
# M Ntini              1
# ...

# %%
ipl_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\ipl-matches.csv')
finals_qual1 = ipl_df[~(ipl_df['MatchNumber'].str.isdigit()) & ~(ipl_df['MatchNumber'] == 'Eliminator')]
finals_qual1.shape
# Out:
# (49, 20)

# %%
potm1 = finals_qual1['Player_of_Match'].value_counts()
print(f'len(potm1): {len(potm1)}')
potm1
# Out:
# len(potm1): 38
# F du Plessis         3
# KA Pollard           3
# SR Watson            2
# JJ Bumrah            2
# M Vijay              2
# YK Pathan            2
# MK Pandey            2
# SK Raina             2
# A Kumble             2
# MM Patel             1
# CH Gayle             1
# DE Bollinger         1
# MS Dhoni             1
# AC Gilchrist         1
# MS Bisla             1
# MEK Hussey           1
# Harbhajan Singh      1
# UT Yadav             1
# V Sehwag             1
# HH Pandya            1
# RG Sharma            1
# A Nehra              1
# Rashid Khan          1
# DA Miller            1
# VR Iyer              1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# SA Yadav             1
# KH Pandya            1
# JC Buttler           1
# KV Sharma            1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# AB de Villiers       1
# M Ntini              1
# ...

# %%
# how many matches each team has played
display(ipl_df)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
team1_matches = ipl_df['Team1'].value_counts()
print(f'team1_matches:\n{team1_matches}')

print()
team2_matches = ipl_df['Team2'].value_counts()
print(f'team2_matches:\n{team2_matches}')
# Out:
# team1_matches:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64
#
# team2_matches:
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# ...

# %%
team1_matches = ipl_df['Team1'].value_counts()
# team1_matches = ipl_df['Team1']
print(f'team1_matches:\n{team1_matches}')

print()
team2_matches = ipl_df['Team2'].value_counts()
print(f'team2_matches:\n{team2_matches}')

team_matches = team1_matches + team2_matches
team_matches
# Out:
# team1_matches:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64
#
# team2_matches:
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# ...

# %%
# sort_values -> ascending -> na_position -> inplace -> multiple cols

# %%
'123 a'.isdigit()
# Out:
# False

# %%
movies = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\movies.csv')
display(movies)
movies.drop(['poster_path','wiki_link'],axis=1,inplace=True)
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
import pandas as pd

ipl_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\ipl-matches.csv')
ipl_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
print(f'rows, cols of ipl_df: {ipl_df.shape}')
print(f'ipl_df data types:\n{ipl_df.dtypes}')
ipl_df.values
# Out:
# rows, cols of ipl_df: (950, 20)
# ipl_df data types:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
# ...

# %%
ipl_sample = ipl_df.sample(5)
ipl_sample
# Out:
#           ID       City        Date   Season MatchNumber  \
# 162  1216526  Abu Dhabi  2020-10-16  2020/21          32
# 366  1082597     Mumbai  2017-04-09     2017           7
# 752   501221     Mumbai  2011-04-22     2011          25
# 489   829709       Pune  2015-04-10     2015           3
# 857   392216  Kimberley  2009-05-09     2009          36
#
#                      Team1                  Team2  \
# 162  Kolkata Knight Riders         Mumbai Indians
# 366         Mumbai Indians  Kolkata Knight Riders
# 752         Mumbai Indians    Chennai Super Kings
# 489        Kings XI Punjab       Rajasthan Royals
# 857        Deccan Chargers        Kings XI Punjab
#
#                                        Venue             TossWinner  \
# 162                     Sheikh Zayed Stadium  Kolkata Knight Riders
# 366                         Wankhede Stadium         Mumbai Indians
# 752                         Wankhede Stadium    Chennai Super Kings
# ...

# %%
# getting stats and info of dataframe
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# getting statistics
ipl_df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# getting number of Null values
ipl_df.isnull()  # returns True/False for the entire dataframe
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
# getting number of Null values
# ipl_df.isnull()  # returns True/False for the entire dataframe
ipl_df.isnull().sum()  # returns total number of null values for each column in the dataframe
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicates - using duplicated()
movies_df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\movies.csv')
movies_df.duplicated()  # returns True/False for duplicate/non-duplicate
movies_df.duplicated().sum()
# Out:
# 0

# %%
student_dict = {
    'name':['nitish','ankit','rupesh','rishabh','ankit','ankita'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students_df = pd.DataFrame(student_dict)
students_df
# Out:
#       name   iq  marks  package
# 0   nitish  100     80       10
# 1    ankit   90     70        7
# 2   rupesh  120    100       14
# 3  rishabh   80     50        2
# 4    ankit    0      0        0
# 5   ankita    0      0        0

# %%
students_df.duplicated().sum()  # checking complete row
# Out:
# 0

# %%
students_df.rename(columns={'marks':'percent','package':'lpa'},inplace=True)
students_df
# Out:
#       name   iq  percent  lpa
# 0   nitish  100       80   10
# 1    ankit   90       70    7
# 2   rupesh  120      100   14
# 3  rishabh   80       50    2
# 4    ankit    0        0    0
# 5   ankita    0        0    0

# %% [markdown]
# Math methods

# %%
students_df.sum()
# Out:
# name       nitishankitrupeshrishabhankitankita
# iq                                         390
# percent                                    300
# lpa                                         33
# dtype: object

# %%
students_df['iq'].sum()
# Out:
# 390

# %%
# from Geeks for Geeks
  
# Creating the dataframe 
df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\nba.csv')
  
# Print the dataframe
display(df)

# find sum
df.sum(axis = 0, skipna = True)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# from Geeks for Geeks
  
# Creating the dataframe 
df = pd.read_csv(r'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A\\Datasets\\nba.csv')
  
# Print the dataframe
display(df)

# find sum
df.sum(skipna = True)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
display(students_df)
print(f'iq: {(100 + 90 + 120 + 80) / 6}')
print(f'percent: {(80 + 70 + 100 + 50) / 6}')
print(f'lpa: {(10 + 7 + 14 + 2) / 6}')
students_df.mean()
# Out:
#       name   iq  percent  lpa
# 0   nitish  100       80   10
# 1    ankit   90       70    7
# 2   rupesh  120      100   14
# 3  rishabh   80       50    2
# 4    ankit    0        0    0
# 5   ankita    0        0    0
# iq: 65.0
# percent: 50.0
# lpa: 5.5
# C:\Users\CICD STUDENT\AppData\Local\Temp\ipykernel_14912\71020359.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_df.mean()
# iq         65.0
# percent    50.0
# lpa         5.5
# dtype: float64

# %%
students_df.var()
# Out:
# C:\Users\CICD STUDENT\AppData\Local\Temp\ipykernel_14912\3581383995.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_df.var()
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %%
students_df.std()
# Out:
# C:\Users\CICD STUDENT\AppData\Local\Temp\ipykernel_14912\1652949286.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_df.std()
# iq         52.057660
# percent    41.952354
# lpa         5.787918
# dtype: float64

# %%
# selecting multiple columns
ipl_df[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
# selecting rows - iloc
ipl_df.iloc[[0,4,5]]
# Out:
#         ID       City        Date Season MatchNumber                Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final     Rajasthan Royals
# 4  1304116     Mumbai  2022-05-22   2022          70  Sunrisers Hyderabad
# 5  1304115     Mumbai  2022-05-21   2022          69       Delhi Capitals
#
#             Team2                             Venue           TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals
# 4    Punjab Kings          Wankhede Stadium, Mumbai  Sunrisers Hyderabad
# 5  Mumbai Indians          Wankhede Stadium, Mumbai       Mumbai Indians
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
# 4          bat         N    Punjab Kings  Wickets     5.0    NaN
# 5        field         N  Mumbai Indians  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# ...

# %%
import pandas as pd

student_dict = {
    'name':['nitish','ankit','rupesh','rishabh','amit','ankita'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students_df = pd.DataFrame(student_dict)

# %%
# selecting rows - loc
display(students_df)
students_df.set_index('name', inplace=True)
print(students_df.index)
students_df.loc[['nitish', 'rupesh' ,'ankita']]
# Out:
#       name   iq  marks  package
# 0   nitish  100     80       10
# 1    ankit   90     70        7
# 2   rupesh  120    100       14
# 3  rishabh   80     50        2
# 4     amit    0      0        0
# 5   ankita    0      0        0
# Index(['nitish', 'ankit', 'rupesh', 'rishabh', 'amit', 'ankita'], dtype='object', name='name')
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14
# ankita    0      0        0

# %%
students_df.loc['nitish']
# Out:
# iq         100
# marks       80
# package     10
# Name: nitish, dtype: int64

# %% [markdown]
# Filtering dataframe

# %%
ipl_df = pd.read_csv('ipl-matches.csv')
ipl_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find all the final winners
mask = ipl_df['MatchNumber'] == 'Final'
new_df = ipl_df[mask]
new_df[['Season','WinningTeam']]

# ipl_df[ipl_df['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl_df[ipl_df['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super finishes have occurred

ipl_df[ipl_df['SuperOver'] == 'Y']  # returns dataframe
ipl_df[ipl_df['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
print(ipl_df.columns)
ipl_df[(ipl_df['City'] == 'Kolkata') & (ipl_df['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
# 5

# %%
# toss winner is match winner (percentage)
ipl_df[ipl_df['TossWinner'] == ipl_df['WinningTeam']].shape[0] * 100 / len(ipl_df)
# Out:
# 51.473684210526315

# %%
ipl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# Toss decision plot
ipl_df['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='TossDecision'>

# %%
# how many matches each team has played - another way
ipl_df['Team1'].value_counts() + ipl_df['Team2'].value_counts()  # returns unsorted
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# dtype: int64

# %%
# how many matches each team has played - another way
(ipl_df['Team1'].value_counts() + ipl_df['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']

    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

points_df['distance'] = points_df.apply(euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000

# %%
students_df.drop_duplicates()
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# amit       0      0        0

# %%
# drop(series + dataframe)
temp = pd.Series([10,2,3,16,45,78,10])
temp
# Out:
# 0    10
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
temp.drop(index=[0,6])
# Out:
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# dtype: int64
