# %% [markdown]
# Data generated from http://roycekimmons.com/tools/generated_data

# %%
pwd
# Out:
# 'C:\\Users\\CICD STUDENT\\Desktop\\Data-Analytics-A'

# %%
import pandas as pd

office_sales_df = pd.read_csv('dm_office_sales.csv')
office_sales_df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0  office supplies  associate's degree               1                5
# 1      peripherals  associate's degree               2                5
# 2  office supplies  associate's degree               2                6
# 3  office supplies        some college               2                0
# 4  office supplies  associate's degree               0                4
#
#    salary   sales
# 0   80032  252601
# 1   85158  296614
# 2   92766  427656
# 3   51172  171721
# 4   67176  211756

# %%
# office_sales_df.info  # returns dataframe of info
office_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
office_sales_df.columns
# Out:
# Index(['division', 'level of education', 'training level', 'work experience',
#        'salary', 'sales'],
#       dtype='object')

# %% [markdown]
# ### Scatterplot

# %%
import seaborn as sns

sns.scatterplot(x='salary', y='sales', data=office_sales_df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %% [markdown]
# We can connect Seaborn plots to MatPlotLib's figsize

# %%
import matplotlib.pyplot as plt

# plt.figure(figsize=(12, 8), dpi=100)
plt.figure(figsize=(8, 4), dpi=100)
sns.scatterplot(x='salary', y='sales', data=office_sales_df)
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# adding hue parameter

plt.figure(figsize=(8, 4), dpi=100)
sns.scatterplot(x='salary', y='sales', data=office_sales_df, hue='division')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>

# %%
# adding palette parameter

plt.figure(figsize=(10, 6), dpi=100)
sns.scatterplot(x='salary',y='sales',data=office_sales_df,hue='work experience', palette='viridis')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>
